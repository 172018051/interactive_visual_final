# %% [markdown]
# # 数据故事

# %% [markdown]
# 数据源渠道：
# - 胡润 http://www.hurun.net/CN/Home/Index
# - 联合国 https://population.un.org/wpp/Download/Standard/Population/
# - 世界银行 https://data.worldbank.org.cn/indicator?tab=all
# - 中国产业信息 https://www.chyxx.com/research/201911/804431.html
# - 国家统计局 http://www.stats.gov.cn/
# - data.world
# - 中商产品研究院 http://s.askci.com/data/year/a0p/

# %% [markdown]
#  双十一，成交 数据
# 中大南方双十一交易数据
#
# 四六级通过与否 男女
# 年级，未来就业？
#
# 食品安全问题
#
# 国家统计局：
# 收支基本情况  月可支配收入
# 结婚离婚率    什么地区高？什么原因造成的？和什么有关
#
# 年龄段、男女、地区

# %% [raw]
# 数据来源：国家统计局

# %%
import pandas as pd
data = pd.read_csv('分省年度数据，粗离婚率%.csv',engine='python') #

# %%
data2 = pd.read_csv('学历.csv',engine='python') 
data2
# 注：2005年、2015年为1%人口抽样调查样本数据，其他年份为1‰人口变动调查样本数据。具体抽样比详见出版物中《中国统计年鉴》,六岁及六岁以上大专及以上人口数（人口抽样调查，人）。
# Out:
#      地区  2018年  2017年  2016年   2015年  2014年  2013年  2012年  2011年
# 0    北京   8121   7967   7729  134106   6420   6859   6143   5597
# 1    天津   3458   3503   3176   53240   2727   2670   2553   2313
# 2    河北   6427   5736   5966  108825   4447   4307   3232   3045
# 3    山西   4445   4272   3941   73661   2799   3013   2707   2347
# 4   内蒙古   3794   3551   3640   59527   2126   1966   2364   2532
# 5    辽宁   5724   5988   6331  110524   6013   6924   6519   4500
# 6    吉林   2881   3164   3093   53934   2578   2509   1955   2031
# 7   黑龙江   4155   4049   4159   76013   3744   3708   3093   2945
# 8    上海   5989   6418   5791  102157   5156   4703   4392   4063
# 9    江苏   9281  10739  10458  190987   8796   8462   8373   7651
# 10   浙江   7005   6850   6705  118847   6510   7464   6473   5547
# 11   安徽   5867   4515   4515  103688   4862   4186   4721   3218
# 12   福建   3965   4418   3421   70991   3366   2554   2262   3583
# ...

# %%
D = list(data.地区)

# %%
D
# Out:
# ['北京',
#  '天津',
#  '河北',
#  '山西',
#  '内蒙古',
#  '辽宁',
#  '吉林',
#  '黑龙江',
#  '上海',
#  '江苏',
#  '浙江',
#  '安徽',
#  '福建',
#  '江西',
#  '山东',
#  '河南',
#  '湖北',
#  '湖南',
#  '广东',
#  '广西',
#  '海南',
#  '重庆',
#  '四川',
#  '贵州',
#  '云南',
#  '西藏',
#  '陕西',
#  '甘肃',
#  '青海',
#  '宁夏',
#  '新疆']

# %%
A=data.values
A
# Out:
# array([['北京', 3.43, 3.71, 4.89, 3.79, 3.08, 3.06, 2.35, 3.45, 2.37],
#        ['天津', 4.11, 3.78, 4.24, 3.36, 2.98, 3.07, 2.57, 3.24, 2.37],
#        ['河北', 3.11, 3.1, 2.96, 2.68, 2.52, 2.44, 2.35, 2.14, 2.04],
#        ['山西', 2.36, 2.23, 2.09, 1.97, 1.8, 1.68, 1.46, 1.37, 1.23],
#        ['内蒙古', 3.9, 4.0, 3.92, 3.66, 3.54, 3.23, 2.83, 2.72, 2.31],
#        ['辽宁', 3.95, 3.81, 3.65, 3.48, 3.48, 3.47, 3.22, 3.27, 2.94],
#        ['吉林', 4.75, 4.9, 4.71, 4.63, 4.44, 4.51, 4.03, 3.72, 3.43],
#        ['黑龙江', 5.12, 5.19, 4.91, 4.98, 4.88, 4.65, 4.09, 3.89, 3.6],
#        ['上海', 2.44, 2.43, 3.41, 2.76, 2.54, 2.88, 2.22, 3.39, 2.08],
#        ['江苏', 3.54, 3.59, 3.27, 2.87, 2.75, 2.73, 2.29, 2.23, 2.04],
#        ['浙江', 2.71, 2.8, 2.65, 2.52, 2.47, 2.41, 2.24, 2.43, 2.09],
#        ['安徽', 3.88, 3.89, 3.54, 2.95, 2.82, 2.59, 2.23, 1.75, 1.82],
#        ['福建', 2.72, 2.72, 2.51, 2.33, 2.3, 2.19, 2.0, 1.89, 1.66],
#        ['江西', 2.7, 2.41, 2.24, 2.08, 1.97, 1.9, 1.68, 1.49, 1.46],
# ...

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Bar, Page, Pie, Timeline
from pyecharts.charts import Map

# %%
year = data.columns.values
x = year.tolist()
del x[-1:1]
x
# Out:
# ['地区',
#  '2018年',
#  '2017年',
#  '2016年',
#  '2015年',
#  '2014年',
#  '2013年',
#  '2012年',
#  '2011年',
#  '2010年']

# %%
for i in range(20010, 2018):
    print(list(zip(list(D),list(data["{}年".format(i)]))))

# %%
def timeline_map() -> Timeline:
    tl = Timeline()
    for i in range(2010, 2018):
        map0 = (
            Map()
            .add(
                "粗离婚率",list(zip(list(D),list(data["{}年".format(i)]))),"china",is_map_symbol_show = False
            )
            .set_global_opts(
                title_opts=opts.TitleOpts(title="中国各省{}年粗离婚率".format(i),subtitle="",
                                          subtitle_textstyle_opts=opts.TextStyleOpts(color="red",font_size=18,font_style="italic")),
                visualmap_opts=opts.VisualMapOpts(min_=0,max_=5),
            
            )
        )
        tl.add(map0,"{}年".format(i))
    return tl

# %%
timeline_map().render()
# Out:
# 'C:\\Users\\如梦令\\render.html'

# %%
图书出版种数 = timeline_map()
图书出版种数.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="c05e60a82c7449afb593d4812285a44d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_c05e60a82c7449afb593d4812285a44d = echarts.init(
#                     document.getElementById('c05e60a82c7449afb593d4812285a44d'), 'white', {renderer: 'canvas'});
#                 var option_c05e60a82c7449afb593d4812285a44d = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "map",
#                 "name": "\u7c97\u79bb\u5a5a\u7387",
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "mapType": "china",
# ...

# %%
# x and y given as array_like objects
import plotly.express as px
fig = px.scatter(x=[0, 1, 2, 3, 4], y=[0, 1, 4, 9, 16])
fig.show()
# Out:
# <div>
#
#
#             <div id="9e759fb9-0c37-45c6-a412-e1772fbe87e3" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9e759fb9-0c37-45c6-a412-e1772fbe87e3")) {
#                     Plotly.newPlot(
#                         '9e759fb9-0c37-45c6-a412-e1772fbe87e3',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>y=%{y}", "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scatter", "x": [0, 1, 2, 3, 4], "xaxis": "x", "y": [0, 1, 4, 9, 16], "yaxis": "y"}],
# ...

# %%
# x and y given as array_like objects
import plotly.express as px
from plotly.offline.offline import _plot_html
fig = px.scatter(x=[0, 1, 2, 3, 4], y=[0, 1, 4, 9, 16])
plotly.offline.plot(data, filename='file.html')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-62-3b2b6d5e6190> in <module>()
#       1 # x and y given as array_like objects
#       2 import plotly.express as px
# ----> 3 from plotly.offline.offline import _plot_html
#       4 fig = px.scatter(x=[0, 1, 2, 3, 4], y=[0, 1, 4, 9, 16])
#       5 plotly.offline.plot(data, filename='file.html')
#
# ImportError: cannot import name '_plot_html' from 'plotly.offline.offline' (C:\anaconda\lib\site-packages\plotly\offline\offline.py)

# %%
import pyecharts.options as opts
from pyecharts.faker import  Faker
from pyecharts.charts import Line


def line_base() -> Line:
    c = (
        Line()
        .add_xaxis(Faker.choose())
        .add_yaxis("data", data.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例"))
    )
    return c
    c.render()

# %%
折线图 = line_xaxis_type()
折线图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5ceed3614c39452db5cb1230f8fabfac" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5ceed3614c39452db5cb1230f8fabfac = echarts.init(
#                     document.getElementById('5ceed3614c39452db5cb1230f8fabfac'), 'white', {renderer: 'canvas'});
#                 var option_5ceed3614c39452db5cb1230f8fabfac = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
def line_xaxis_type() -> Line:
    c = (
        Line()
        .add_xaxis(Faker.values())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Line-数值 X 轴"),
            xaxis_opts=opts.AxisOpts(type_="value"),
        )
    )
    return c

# %%
折线图 = line_xaxis_type()
折线图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4d913b0ed24a455e8b93c71798275e9d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4d913b0ed24a455e8b93c71798275e9d = echarts.init(
#                     document.getElementById('4d913b0ed24a455e8b93c71798275e9d'), 'white', {renderer: 'canvas'});
#                 var option_4d913b0ed24a455e8b93c71798275e9d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
def line_smooth() -> Line:
    c = (
        Line()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values(), is_smooth=True)
        .add_yaxis("商家B", Faker.values(), is_smooth=True)
        .set_global_opts(title_opts=opts.TitleOpts(title="Line-smooth"))
    )
    return c

# %%
折线图 = line_smooth()
折线图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="12ccb620dd8e466da668d4986f546918" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_12ccb620dd8e466da668d4986f546918 = echarts.init(
#                     document.getElementById('12ccb620dd8e466da668d4986f546918'), 'white', {renderer: 'canvas'});
#                 var option_12ccb620dd8e466da668d4986f546918 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
def line_yaxis_log() -> Line:
    c = (
        Line()
        .add_xaxis(xaxis_data=["一", "二", "三", "四", "五", "六", "七", "八", "九"])
        .add_yaxis(
            "2 的指数",
            y_axis=[1, 2, 4, 8, 16, 32, 64, 128, 256],
            linestyle_opts=opts.LineStyleOpts(width=2),
        )
        .add_yaxis(
            "3 的指数",
            y_axis=[1, 3, 9, 27, 81, 247, 741, 2223, 6669],
            linestyle_opts=opts.LineStyleOpts(width=2),
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Line-对数轴示例"),
            xaxis_opts=opts.AxisOpts(name="x"),
            yaxis_opts=opts.AxisOpts(
                type_="log",
                name="y",
                splitline_opts=opts.SplitLineOpts(is_show=True),
                is_scale=True,
            ),
        )
    )
    return c

# %%
折线图 = line_yaxis_log()
折线图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a2e63bcab76142ba93938e77edddd13a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a2e63bcab76142ba93938e77edddd13a = echarts.init(
#                     document.getElementById('a2e63bcab76142ba93938e77edddd13a'), 'white', {renderer: 'canvas'});
#                 var option_a2e63bcab76142ba93938e77edddd13a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
import json
import os

from pyecharts import options as opts
from pyecharts.charts import Page, Tree


def tree_base() -> Tree:
    data = [
        {
            "children": [
                {"name": "B"},
                {
                    "children": [
                        {"children": [{"name": "I"}], "name": "E"},
                        {"name": "F"},
                    ],
                    "name": "C",
                },
                {
                    "children": [
                        {"children": [{"name": "J"}, {"name": "K"}], "name": "G"},
                        {"name": "H"},
                    ],
                    "name": "D",
                },
            ],
            "name": "A",
        }
    ]
    c = (
        Tree()
        .add("", data)
        .set_global_opts(title_opts=opts.TitleOpts(title="Tree-基本示例"))
    )
    return c

# %%
折线图 = tree_base()
折线图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0a9419f659594400b3f9f4fa51d189a3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0a9419f659594400b3f9f4fa51d189a3 = echarts.init(
#                     document.getElementById('0a9419f659594400b3f9f4fa51d189a3'), 'white', {renderer: 'canvas'});
#                 var option_0a9419f659594400b3f9f4fa51d189a3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.components import Table
from pyecharts.options import ComponentTitleOpts


def table_base() -> Table:
    table = Table()

    headers = ["City name", "Area", "Population", "Annual Rainfall"]
    rows = [
        ["Brisbane", 5905, 1857594, 1146.4],
        ["Adelaide", 1295, 1158259, 600.5],
        ["Darwin", 112, 120900, 1714.7],
        ["Hobart", 1357, 205556, 619.5],
        ["Sydney", 2058, 4336374, 1214.8],
        ["Melbourne", 1566, 3806092, 646.9],
        ["Perth", 5386, 1554769, 869.4],
    ]
    table.add(headers, rows).set_global_opts(
        title_opts=ComponentTitleOpts(title="Table-我是主标题", subtitle="我是副标题支持换行哦")
    )
    return table

# %%
表格 = table_base()
表格.render_notebook()
# Out:
#             <style>
#             .fl-table {
#                 margin: 20px;
#                 border-radius: 5px;
#                 font-size: 12px;
#                 border: none;
#                 border-collapse: collapse;
#                 max-width: 100%;
#                 white-space: nowrap;
#                 word-break: keep-all;
#             }
#
#             .fl-table th {
#                 text-align: left;
#                 font-size: 20px;
#             }
#
#             .fl-table tr {
#                 display: table-row;
#                 vertical-align: inherit;
#                 border-color: inherit;
#             }
#
#             .fl-table tr:hover td {
#                 background: #00d1b2;
#                 color: #F8F8F8;
#             }
#
#             .fl-table td, .fl-table th {
#                 border-style: none;
#                 border-top: 1px solid #dbdbdb;
#                 border-left: 1px solid #dbdbdb;
# ...

# %%
from pyecharts.components import Image
from pyecharts.options import ComponentTitleOpts


def image_base() -> Image:
    image = Image()

    img_src = (
        "https://user-images.githubusercontent.com/19553554/396123"
        "58-499eb2ae-4f91-11e8-8f56-179c4f0bf2df.png"
    )
    image.add(
        src=img_src,
        style_opts={"width": "200px", "height": "200px", "style": "margin-top: 20px"},
    ).set_global_opts(
        title_opts=ComponentTitleOpts(title="Image-基本示例", subtitle="我是副标题支持换行哦")
    )
    return image

# %%
图片 = image_base()
图片.render_notebook()
# Out:
#             <div id="29b3c73eac4846319b002cadc6dd6920" class="chart-container" style="">
#             <p class="title" style="font-size: 18px; font-weight:bold;" > Image-基本示例</p>
#             <p class="subtitle" style="font-size: 12px;" > 我是副标题支持换行哦</p>
#             <img src="https://user-images.githubusercontent.com/19553554/39612358-499eb2ae-4f91-11e8-8f56-179c4f0bf2df.png" width="200px" height="200px" style="margin-top: 20px" />
#         </div>

# %%
import json
import os

from pyecharts import options as opts
from pyecharts.charts import Graph, Page


def graph_base() -> Graph:
    nodes = [
        {"name": "结点1", "symbolSize": 10},
        {"name": "结点2", "symbolSize": 20},
        {"name": "结点3", "symbolSize": 30},
        {"name": "结点4", "symbolSize": 40},
        {"name": "结点5", "symbolSize": 50},
        {"name": "结点6", "symbolSize": 40},
        {"name": "结点7", "symbolSize": 30},
        {"name": "结点8", "symbolSize": 20},
    ]
    links = []
    for i in nodes:
        for j in nodes:
            links.append({"source": i.get("name"), "target": j.get("name")})
    c = (
        Graph()
        .add("", nodes, links, repulsion=8000)
        .set_global_opts(title_opts=opts.TitleOpts(title="Graph-基本示例"))
    )
    return c

# %%
图片 = graph_base()
图片.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f0ff0acd71644445a81540b8064f7e4c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f0ff0acd71644445a81540b8064f7e4c = echarts.init(
#                     document.getElementById('f0ff0acd71644445a81540b8064f7e4c'), 'white', {renderer: 'canvas'});
#                 var option_f0ff0acd71644445a81540b8064f7e4c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Scatter


def scatter_base() -> Scatter:
    c = (
        Scatter()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Scatter-基本示例"))
    )
    return c

# %%
散点图 = scatter_base()
散点图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ce33bc1e7da54a8fb0a6ea766c853bf6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ce33bc1e7da54a8fb0a6ea766c853bf6 = echarts.init(
#                     document.getElementById('ce33bc1e7da54a8fb0a6ea766c853bf6'), 'white', {renderer: 'canvas'});
#                 var option_ce33bc1e7da54a8fb0a6ea766c853bf6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
