# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
data = pd.read_csv('分省年度数据，粗离婚率，年升序.csv',engine='python') #
data
# Out:
#      地区  2010年  2011年  2012年  2013年  2014年  2015年  2016年  2017年  2018年
# 0    北京   2.37   3.45   2.35   3.06   3.08   3.79   4.89   3.71   3.43
# 1    天津   2.37   3.24   2.57   3.07   2.98   3.36   4.24   3.78   4.11
# 2    河北   2.04   2.14   2.35   2.44   2.52   2.68   2.96   3.10   3.11
# 3    山西   1.23   1.37   1.46   1.68   1.80   1.97   2.09   2.23   2.36
# 4   内蒙古   2.31   2.72   2.83   3.23   3.54   3.66   3.92   4.00   3.90
# 5    辽宁   2.94   3.27   3.22   3.47   3.48   3.48   3.65   3.81   3.95
# 6    吉林   3.43   3.72   4.03   4.51   4.44   4.63   4.71   4.90   4.75
# 7   黑龙江   3.60   3.89   4.09   4.65   4.88   4.98   4.91   5.19   5.12
# 8    上海   2.08   3.39   2.22   2.88   2.54   2.76   3.41   2.43   2.44
# 9    江苏   2.04   2.23   2.29   2.73   2.75   2.87   3.27   3.59   3.54
# 10   浙江   2.09   2.43   2.24   2.41   2.47   2.52   2.65   2.80   2.71
# 11   安徽   1.82   1.75   2.23   2.59   2.82   2.95   3.54   3.89   3.88
# ...

# %%
def line_base() -> Line:
    c = (
        Line()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values())
        .add_yaxis("商家B", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例"))
    )
    return c
折线图 = line_base()
折线图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8850c73615e94de6a14d4af5ec188a23" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8850c73615e94de6a14d4af5ec188a23 = echarts.init(
#                     document.getElementById('8850c73615e94de6a14d4af5ec188a23'), 'white', {renderer: 'canvas'});
#                 var option_8850c73615e94de6a14d4af5ec188a23 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
 list(data['1'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-3dd77088b432> in <module>()
# ----> 1 list(data['1'])
#
# ...

# %%
df = data.set_index("地区")
df
# Out:
#      2010年  2011年  2012年  2013年  2014年  2015年  2016年  2017年  2018年
# 地区
# 北京    2.37   3.45   2.35   3.06   3.08   3.79   4.89   3.71   3.43
# 天津    2.37   3.24   2.57   3.07   2.98   3.36   4.24   3.78   4.11
# 河北    2.04   2.14   2.35   2.44   2.52   2.68   2.96   3.10   3.11
# 山西    1.23   1.37   1.46   1.68   1.80   1.97   2.09   2.23   2.36
# 内蒙古   2.31   2.72   2.83   3.23   3.54   3.66   3.92   4.00   3.90
# 辽宁    2.94   3.27   3.22   3.47   3.48   3.48   3.65   3.81   3.95
# 吉林    3.43   3.72   4.03   4.51   4.44   4.63   4.71   4.90   4.75
# 黑龙江   3.60   3.89   4.09   4.65   4.88   4.98   4.91   5.19   5.12
# 上海    2.08   3.39   2.22   2.88   2.54   2.76   3.41   2.43   2.44
# 江苏    2.04   2.23   2.29   2.73   2.75   2.87   3.27   3.59   3.54
# 浙江    2.09   2.43   2.24   2.41   2.47   2.52   2.65   2.80   2.71
# 安徽    1.82   1.75   2.23   2.59   2.82   2.95   3.54   3.89   3.88
# 福建    1.66   1.89   2.00   2.19   2.30   2.33   2.51   2.72   2.72
# ...

# %%
df.loc["北京",:]
# Out:
# 2010年    2.37
# 2011年    3.45
# 2012年    2.35
# 2013年    3.06
# 2014年    3.08
# 2015年    3.79
# 2016年    4.89
# 2017年    3.71
# 2018年    3.43
# Name: 北京, dtype: float64

# %%
x = list(data['2018年']) 
x
# Out:
# [3.43,
#  4.11,
#  3.11,
#  2.36,
#  3.9,
#  3.95,
#  4.75,
#  5.12,
#  2.44,
#  3.54,
#  2.71,
#  3.88,
#  2.72,
#  2.7,
#  2.74,
#  3.4,
#  3.4,
#  3.1,
#  2.03,
#  2.62,
#  2.1,
#  4.96,
#  3.76,
#  4.22,
#  2.77,
#  1.37,
#  3.34,
#  2.2,
#  2.85,
#  3.33,
#  2.41]

# %%
df.loc["北京",:]
# Out:
# 2010年    2.37
# 2011年    3.45
# 2012年    2.35
# 2013年    3.06
# 2014年    3.08
# 2015年    3.79
# 2016年    4.89
# 2017年    3.71
# 2018年    3.43
# Name: 北京, dtype: float64

# %%
list(df.columns)
# Out:
# ['2010年',
#  '2011年',
#  '2012年',
#  '2013年',
#  '2014年',
#  '2015年',
#  '2016年',
#  '2017年',
#  '2018年']

# %%
        .add_xaxis(list(df.columns))
        .add_yaxis("华北", list(df.loc["北京",:]) )
        .add_yaxis("华北", list(df.loc["天津",:]) )
        .add_yaxis("华北", list(df.loc["河北",:]) )
        .add_yaxis("华北", list(df.loc["山西",:]) )
        .add_yaxis("华北", list(df.loc["内蒙古",:]) )
        .add_yaxis("东北", list(df.loc["辽宁",:]) )
        .add_yaxis("东北", list(df.loc["吉林",:]) )
        .add_yaxis("东北", list(df.loc["黑龙江",:]) )
        .add_yaxis("华东", list(df.loc["上海",:]) )
        .add_yaxis("华东", list(df.loc["江苏",:]) )
        .add_yaxis("华东", list(df.loc["浙江",:]) )
        .add_yaxis("华东", list(df.loc["安徽",:]) )
        .add_yaxis("华东", list(df.loc["福建",:]) )
        .add_yaxis("华东", list(df.loc["江西",:]) )
        .add_yaxis("中南", list(df.loc["山东",:]) )
        .add_yaxis("中南", list(df.loc["河南",:]) )
        .add_yaxis("中南", list(df.loc["湖北",:]) )
        .add_yaxis("中南", list(df.loc["湖南",:]) )
        .add_yaxis("中南", list(df.loc["广东",:]) )
        .add_yaxis("中南", list(df.loc["广西",:]) )
        .add_yaxis("中南", list(df.loc["海南",:]) )
        .add_yaxis("西南", list(df.loc["重庆",:]) )
        .add_yaxis("西南", list(df.loc["四川",:]) )
        .add_yaxis("西南", list(df.loc["贵州",:]) )
        .add_yaxis("西南", list(df.loc["云南",:]) )
        .add_yaxis("西南", list(df.loc["西藏",:]) )
        .add_yaxis("西北", list(df.loc["陕西",:]) )
        .add_yaxis("西北", list(df.loc["甘肃",:]) )
        .add_yaxis("西北", list(df.loc["青海",:]) )
        .add_yaxis("西北", list(df.loc["宁夏",:]) )
        .add_yaxis("西北", list(df.loc["新疆",:]) )

# %%
import pyecharts.options as opts
from pyecharts.faker import  Faker
from pyecharts.charts import Line
import pandas as pd
from pandas import DataFrame

import numpy as np
data = pd.read_csv('分省年度数据，粗离婚率，年升序.csv',engine='python') #
df = data.set_index("地区")

#itemStyle : { normal: {label : {show: true}}}

def line_base() -> Line:
    series: [
            {
itemStyle : { normal: {label : {show:  False}}}
            }
]
    c = (
        Line()
        .add_xaxis(list(df.columns))
        .add_yaxis("北京",df.loc["北京",:],
                   markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(name="自定义标记点" )]),
                  )
        .add_yaxis("天津",df.loc["天津",:])
        .add_yaxis("河北",df.loc["河北",:])
        .add_yaxis("山西",df.loc["山西",:])
        .add_yaxis("内蒙古",df.loc["内蒙古",:])
        .add_yaxis("辽宁",df.loc["辽宁",:])
        .add_yaxis("吉林",df.loc["吉林",:]) 
        .add_yaxis("黑龙江",df.loc["黑龙江",:])
        .add_yaxis("上海", list(df.loc["上海",:]) )
        .add_yaxis("江苏", list(df.loc["江苏",:]) )
        .add_yaxis("华东", list(df.loc["浙江",:]) )
        .add_yaxis("安徽", list(df.loc["安徽",:]) )
        .add_yaxis("福建", list(df.loc["福建",:]) )
        .add_yaxis("江西", list(df.loc["江西",:]) )
        .add_yaxis("山东", list(df.loc["山东",:]) )
        .add_yaxis("河南", list(df.loc["河南",:]) )
        .add_yaxis("湖北", list(df.loc["湖北",:]) )
        .add_yaxis("湖南", list(df.loc["湖南",:]) )
        .add_yaxis("广东", list(df.loc["广东",:]) )
        .add_yaxis("广西", list(df.loc["广西",:]) )
        .add_yaxis("海南", list(df.loc["海南",:]) )
        .add_yaxis("重庆", list(df.loc["重庆",:]) )
        .add_yaxis("四川", list(df.loc["四川",:]) )
        .add_yaxis("贵州", list(df.loc["贵州",:]) )
        .add_yaxis("云南", list(df.loc["云南",:]) )
        .add_yaxis("西藏", list(df.loc["西藏",:]) )
        .add_yaxis("陕西", list(df.loc["陕西",:]) )
        .add_yaxis("甘肃", list(df.loc["甘肃",:]) )
        .add_yaxis("青海", list(df.loc["青海",:]) )
        .add_yaxis("宁夏", list(df.loc["宁夏",:]) )
        .add_yaxis("新疆", list(df.loc["新疆",:]) )
        
        .set_global_opts(title_opts=opts.TitleOpts(title="全国各省离婚率变化趋势"))
    #    .set_series_opts(
            

        #    markpoint_opts=opts.MarkPointOpts(
         #       data=[opts.MarkPointItem(type_="max"), opts.MarkPointItem(type_="min")],                
          # )
    #)
    )
    return c
折线图 = line_base()
折线图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="56af62053dd74ae8bb9cc1e16919db4d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_56af62053dd74ae8bb9cc1e16919db4d = echarts.init(
#                     document.getElementById('56af62053dd74ae8bb9cc1e16919db4d'), 'white', {renderer: 'canvas'});
#                 var option_56af62053dd74ae8bb9cc1e16919db4d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ## 如何在拐点添加文字信息，每个点可以看到是什么省份的？？
# 换名称  done
# ## 如何把这么多小点去掉？
# ## 怎么做下拉表单，分区？

# %%
#华北
import pyecharts.options as opts
from pyecharts.faker import  Faker
from pyecharts.charts import Line
import pandas as pd
from pandas import DataFrame

import numpy as np
data = pd.read_csv('分省年度数据，粗离婚率，年升序.csv',engine='python') #
df = data.set_index("地区")

#itemStyle : { normal: {label : {show: true}}}

def line_base2() -> Line:
    series: [
            {
itemStyle : { normal: {label : {show:  False}}}
            }
]
    c = (
        Line()
        .add_xaxis(list(df.columns))
        .add_yaxis("北京",df.loc["北京",:],
                   markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(name="自定义标记点" )]),
                  )
        .add_yaxis("天津",df.loc["天津",:])
        .add_yaxis("河北",df.loc["河北",:])
        .add_yaxis("山西",df.loc["山西",:])
        .add_yaxis("内蒙古",df.loc["内蒙古",:])
        
        .set_global_opts(title_opts=opts.TitleOpts(title="中国华北地区离婚率变化趋势"))
    #    .set_series_opts(
            

        #    markpoint_opts=opts.MarkPointOpts(
         #       data=[opts.MarkPointItem(type_="max"), opts.MarkPointItem(type_="min")],                
          # )
    #)
    )
    return c
折线图 = line_base2()
折线图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="995bf7a7cab14168910dd993ac9a27db" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_995bf7a7cab14168910dd993ac9a27db = echarts.init(
#                     document.getElementById('995bf7a7cab14168910dd993ac9a27db'), 'white', {renderer: 'canvas'});
#                 var option_995bf7a7cab14168910dd993ac9a27db = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
#东北
import pyecharts.options as opts
from pyecharts.faker import  Faker
from pyecharts.charts import Line
import pandas as pd
from pandas import DataFrame

import numpy as np
data = pd.read_csv('分省年度数据，粗离婚率，年升序.csv',engine='python') #
df = data.set_index("地区")

#itemStyle : { normal: {label : {show: true}}}

def line_base3() -> Line:
    series: [
            {
itemStyle : { normal: {label : {show:  False}}}
            }
]
    c = (
        Line()
        .add_xaxis(list(df.columns))
        .add_yaxis("辽宁",df.loc["辽宁",:])
        .add_yaxis("吉林",df.loc["吉林",:]) 
        .add_yaxis("黑龙江",df.loc["黑龙江",:])

        
        .set_global_opts(title_opts=opts.TitleOpts(title="中国东北地区离婚率变化趋势"))
    #    .set_series_opts(
            

        #    markpoint_opts=opts.MarkPointOpts(
         #       data=[opts.MarkPointItem(type_="max"), opts.MarkPointItem(type_="min")],                
          # )
    #)
    )
    return c
折线图 = line_base3()
折线图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="21af8539ab1e40dd83ecd3d631db9c55" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_21af8539ab1e40dd83ecd3d631db9c55 = echarts.init(
#                     document.getElementById('21af8539ab1e40dd83ecd3d631db9c55'), 'white', {renderer: 'canvas'});
#                 var option_21af8539ab1e40dd83ecd3d631db9c55 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
#华东
import pyecharts.options as opts
from pyecharts.faker import  Faker
from pyecharts.charts import Line
import pandas as pd
from pandas import DataFrame

import numpy as np
data = pd.read_csv('分省年度数据，粗离婚率，年升序.csv',engine='python') #
df = data.set_index("地区")

#itemStyle : { normal: {label : {show: true}}}

def line_base4() -> Line:
    series: [
            {
itemStyle : { normal: {label : {show:  False}}}
            }
]
    c = (
        Line()
        .add_xaxis(list(df.columns))
        .add_yaxis("上海", list(df.loc["上海",:]) )
        .add_yaxis("江苏", list(df.loc["江苏",:]) )
        .add_yaxis("华东", list(df.loc["浙江",:]) )
        .add_yaxis("安徽", list(df.loc["安徽",:]) )
        .add_yaxis("福建", list(df.loc["福建",:]) )
        .add_yaxis("江西", list(df.loc["江西",:]) )

        
        .set_global_opts(title_opts=opts.TitleOpts(title="中国华东地区离婚率变化趋势"))
    #    .set_series_opts(
            

        #    markpoint_opts=opts.MarkPointOpts(
         #       data=[opts.MarkPointItem(type_="max"), opts.MarkPointItem(type_="min")],                
          # )
    #)
    )
    return c
折线图 = line_base4()
折线图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7c40245c3f4e4b0ebde645c8dc5fd439" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7c40245c3f4e4b0ebde645c8dc5fd439 = echarts.init(
#                     document.getElementById('7c40245c3f4e4b0ebde645c8dc5fd439'), 'white', {renderer: 'canvas'});
#                 var option_7c40245c3f4e4b0ebde645c8dc5fd439 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
#中南
import pyecharts.options as opts
from pyecharts.faker import  Faker
from pyecharts.charts import Line
import pandas as pd
from pandas import DataFrame

import numpy as np
data = pd.read_csv('分省年度数据，粗离婚率，年升序.csv',engine='python') #
df = data.set_index("地区")

#itemStyle : { normal: {label : {show: true}}}

def line_base5() -> Line:
    series: [
            {
itemStyle : { normal: {label : {show:  False}}}
            }
]
    c = (
        Line()
        .add_xaxis(list(df.columns))
        .add_yaxis("山东", list(df.loc["山东",:]) )
        .add_yaxis("河南", list(df.loc["河南",:]) )
        .add_yaxis("湖北", list(df.loc["湖北",:]) )
        .add_yaxis("湖南", list(df.loc["湖南",:]) )
        .add_yaxis("广东", list(df.loc["广东",:]) )
        .add_yaxis("广西", list(df.loc["广西",:]) )
        .add_yaxis("海南", list(df.loc["海南",:]) )

        
        .set_global_opts(title_opts=opts.TitleOpts(title="中国中南地区离婚率变化趋势"))
    #    .set_series_opts(
            

        #    markpoint_opts=opts.MarkPointOpts(
         #       data=[opts.MarkPointItem(type_="max"), opts.MarkPointItem(type_="min")],                
          # )
    #)
    )
    return c
折线图 = line_base5()
折线图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1865bd0fb9be4e43a3459c286978a0bd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1865bd0fb9be4e43a3459c286978a0bd = echarts.init(
#                     document.getElementById('1865bd0fb9be4e43a3459c286978a0bd'), 'white', {renderer: 'canvas'});
#                 var option_1865bd0fb9be4e43a3459c286978a0bd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
#西南
import pyecharts.options as opts
from pyecharts.faker import  Faker
from pyecharts.charts import Line
import pandas as pd
from pandas import DataFrame

import numpy as np
data = pd.read_csv('分省年度数据，粗离婚率，年升序.csv',engine='python') #
df = data.set_index("地区")

#itemStyle : { normal: {label : {show: true}}}

def line_base6() -> Line:
    series: [
            {
itemStyle : { normal: {label : {show:  False}}}
            }
]
    c = (
        Line()
        .add_xaxis(list(df.columns))
        .add_yaxis("重庆", list(df.loc["重庆",:]) )
        .add_yaxis("四川", list(df.loc["四川",:]) )
        .add_yaxis("贵州", list(df.loc["贵州",:]) )
        .add_yaxis("云南", list(df.loc["云南",:]) )
        .add_yaxis("西藏", list(df.loc["西藏",:]) )

        
        .set_global_opts(title_opts=opts.TitleOpts(title="中国西南地区离婚率变化趋势"))
    #    .set_series_opts(
            

        #    markpoint_opts=opts.MarkPointOpts(
         #       data=[opts.MarkPointItem(type_="max"), opts.MarkPointItem(type_="min")],                
          # )
    #)
    )
    return c
折线图 = line_base6()
折线图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2c19c12bae6742fc9aba8b3ccd749064" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2c19c12bae6742fc9aba8b3ccd749064 = echarts.init(
#                     document.getElementById('2c19c12bae6742fc9aba8b3ccd749064'), 'white', {renderer: 'canvas'});
#                 var option_2c19c12bae6742fc9aba8b3ccd749064 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
#西北
import pyecharts.options as opts
from pyecharts.faker import  Faker
from pyecharts.charts import Line
import pandas as pd
from pandas import DataFrame

import numpy as np
data = pd.read_csv('分省年度数据，粗离婚率，年升序.csv',engine='python') #
df = data.set_index("地区")

#itemStyle : { normal: {label : {show: true}}}

def line_base7() -> Line:
    series: [
            {
itemStyle : { normal: {label : {show:  False}}}
            }
]
    c = (
        Line()
        .add_xaxis(list(df.columns))
        .add_yaxis("陕西", list(df.loc["陕西",:]) )
        .add_yaxis("甘肃", list(df.loc["甘肃",:]) )
        .add_yaxis("青海", list(df.loc["青海",:]) )
        .add_yaxis("宁夏", list(df.loc["宁夏",:]) )
        .add_yaxis("新疆", list(df.loc["新疆",:]) )
        
        .set_global_opts(title_opts=opts.TitleOpts(title="中国西北地区离婚率变化趋势"))
    #    .set_series_opts(
            

        #    markpoint_opts=opts.MarkPointOpts(
         #       data=[opts.MarkPointItem(type_="max"), opts.MarkPointItem(type_="min")],                
          # )
    #)
    )
    return c
折线图 = line_base7()
折线图.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6120a08961284f26aad806a6f4135b0f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6120a08961284f26aad806a6f4135b0f = echarts.init(
#                     document.getElementById('6120a08961284f26aad806a6f4135b0f'), 'white', {renderer: 'canvas'});
#                 var option_6120a08961284f26aad806a6f4135b0f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
